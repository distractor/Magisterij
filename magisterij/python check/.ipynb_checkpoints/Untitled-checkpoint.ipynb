# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
errorMean=[18.7007,17.0293,18.0927,16.5574,17.3693,16.9280,18.4835,18.7815,19.0203,17.5392,19.4717,18.1876]
errorLinReg=[16.4010,14.5543,14.4843,16.1514,12.7125,13.7903,16.2465,13.2701,16.8605,16.3459,16.7160,13.7631]
errorGPfitc=[8.4009,8.6981,9.0372,5.6901,4.0968,7.5598,7.0954,6.0798,12.5640,6.1908,7.3118,5.8021]
errorDeepGP=[4.1111,4.6824,4.0957,1.8768,0.8841,1.4188,0.8424,16.0562,7.1533,2.3394,1.0989,1.7476]
errorDeepGPNoCovars=[4.0935,4.5214,4.1072,1.8895,0.8730,1.3988,0.8407,18.8080,7.2025,2.4060,1.0953,1.7417]
errorDeepGPIn=[4.4530,5.6714,4.5512,1.9702,1.8343,1.9087,1.1459,18.6520,7.1654,11.6541,3.8991,1.9246]
errorRecDeepGP=[1.0308,3.5906,0.7667,0.3204,0.2570,0.5622,0.4932,16.5227,2.0878,0.7435,0.5376,0.6726]
errorRecDeepGPNoCovars=[1.0106,3.4000,0.7525,0.3173,0.2484,0.5546,0.4895,15.8602,2.0636,0.7292,0.5300,0.6642]

# %%
plt.plot(errorMean, label='Mean')
plt.plot(errorLinReg, label='LinReg')
plt.plot(errorGPfitc, label='GPfitc')
plt.plot(errorDeepGP, label='DeepGP')
plt.plot(errorDeepGPNoCovars, label='DeepGPNoCovars')
plt.plot(errorDeepGPIn, label='DeepGPIn')
plt.plot(errorRecDeepGP, label='RecDeepGP')
plt.plot(errorRecDeepGPNoCovars, label='RecDeepGPNoCovars')
plt.legend(shadow=True,bbox_to_anchor=(1.05, 1.05))
plt.show()
